# %% [markdown]
# # Educational Data Understanding
# ### A Part of IBM Data Science Capstone Project

# %%
#Importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#importing dataset as df
df= pd.read_excel('Final Dataset.xlsx')

# %%
#Data Understanding
df.describe()
# Out:
#            IDNumber        10th         10B  ...       Sgpa6       Sgpa7       Sgpa8
# count    238.000000  238.000000  238.000000  ...  238.000000  238.000000  238.000000
# mean   12516.533613   77.725134    1.369748  ...    7.743277    8.692437    8.139118
# std     1359.381023    9.695173    0.621222  ...    1.403194    1.444220    1.525816
# min     1184.000000   44.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%    12283.500000   71.017500    1.000000  ...    7.130000    8.450000    7.792500
# 50%    12637.500000   79.335000    1.000000  ...    7.920000    8.830000    8.410000
# 75%    13076.000000   84.180000    2.000000  ...    8.620000    9.545000    8.930000
# max    13393.000000   96.000000    4.000000  ...    9.810000   10.000000   10.000000
#
# [8 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238 entries, 0 to 237
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   IDNumber  238 non-null    int64
#  1   10th      238 non-null    float64
#  2   10B       238 non-null    int64
#  3   12th      238 non-null    float64
#  4   12B       238 non-null    int64
#  5   Sgpa1     238 non-null    float64
#  6   Sgpa2     238 non-null    float64
#  7   Sgpa3     238 non-null    float64
#  8   Sgpa4     238 non-null    float64
#  9   Sgpa5     238 non-null    float64
#  10  Sgpa6     238 non-null    float64
#  11  Sgpa7     238 non-null    float64
#  12  Sgpa8     238 non-null    float64
# dtypes: float64(10), int64(3)
# memory usage: 24.3 KB

# %%
#data visualization
ax = sns.boxplot(x=df["Sgpa1"])

# %%
'''Part 1: For Semester 1 Student who wants to predict semester 2 performance'''
#defining X and Y
X1= df.iloc[:,1:6].values
Y1= df.iloc[:,6].values

#Splitting the data
from sklearn.model_selection import train_test_split
X1_train, X1_test, Y1_train, Y1_test= train_test_split(X1,Y1,test_size= 1/10, random_state=6)

#Fitting Simple Linear Regression 
#This is called Model 
from sklearn.linear_model import LinearRegression
regressor1= LinearRegression()
regressor1.fit(X1_train,Y1_train)

##Predicting the test results
Y1_pred= regressor1.predict(X1_test)

#printing accuracy of model
accuracy = regressor1.score(X1_test,Y1_test)
#print(accuracy*100,'%')

'''Part 2: For Semester 2 Student who wants to predict semester 3 performance'''
#defining X and Y
X2= df.iloc[:,1:7].values
Y2= df.iloc[:,7].values

#Splitting the data
from sklearn.model_selection import train_test_split
X2_train, X2_test, Y2_train, Y2_test= train_test_split(X2,Y2,test_size= 1/10, random_state=6)

#Fitting Simple Linear Regression 
#This is called Model 
from sklearn.linear_model import LinearRegression
regressor2= LinearRegression()
regressor2.fit(X2_train,Y2_train)

##Predicting the test results
Y2_pred= regressor2.predict(X2_test)

#printing accuracy of model
accuracy2 = regressor2.score(X2_test,Y2_test)
#print(accuracy2*100,'%')

'''Part 3: For Semester 3 Student who wants to predict semester 4 performance'''
#defining X and Y
X3= df.iloc[:,1:8].values
Y3= df.iloc[:,8].values

#Splitting the data
from sklearn.model_selection import train_test_split
X3_train, X3_test, Y3_train, Y3_test= train_test_split(X3,Y3,test_size= 1/10, random_state=1)

#Fitting Simple Linear Regression 
#This is called Model 
from sklearn.linear_model import LinearRegression
regressor3= LinearRegression()
regressor3.fit(X3_train,Y3_train)

##Predicting the test results
Y3_pred= regressor3.predict(X3_test)

#printing accuracy of model
accuracy3 = regressor3.score(X3_test,Y3_test)
#print(accuracy3*100,'%')

'''Part 4: For Semester 4 Student who wants to predict semester 5 performance'''
#defining X and Y
X4= df.iloc[:,1:9].values
Y4= df.iloc[:,9].values

#Splitting the data
from sklearn.model_selection import train_test_split
X4_train, X4_test, Y4_train, Y4_test= train_test_split(X4,Y4,test_size= 1/10, random_state=1)

#Fitting Simple Linear Regression 
#This is called Model 
from sklearn.linear_model import LinearRegression
regressor4= LinearRegression()
regressor4.fit(X4_train,Y4_train)

##Predicting the test results
Y4_pred= regressor4.predict(X4_test)

#printing accuracy of model
accuracy4 = regressor4.score(X4_test,Y4_test)
#print(accuracy4*100,'%')

'''Part 5: For Semester 5 Student who wants to predict semester 6 performance'''
#defining X and Y
X5= df.iloc[:,1:10].values
Y5= df.iloc[:,10].values

#Splitting the data
from sklearn.model_selection import train_test_split
X5_train, X5_test, Y5_train, Y5_test= train_test_split(X5,Y5,test_size= 1/10, random_state=1)

#Fitting Simple Linear Regression 
#This is called Model 
from sklearn.linear_model import LinearRegression
regressor5= LinearRegression()
regressor5.fit(X5_train,Y5_train)

##Predicting the test results
Y5_pred= regressor5.predict(X5_test)

#printing accuracy of model
accuracy5 = regressor5.score(X5_test,Y5_test)
#print(accuracy5*100,'%')


'''Part 6: For Semester 6 Student who wants to predict semester 7 performance'''
#defining X and Y
X6= df.iloc[:,1:11].values
Y6= df.iloc[:,11].values

#Splitting the data
from sklearn.model_selection import train_test_split
X6_train, X6_test, Y6_train, Y6_test= train_test_split(X6,Y6,test_size= 1/10, random_state=6)

#Fitting Simple Linear Regression 
#This is called Model 
from sklearn.linear_model import LinearRegression
regressor6= LinearRegression()
regressor6.fit(X6_train,Y6_train)

##Predicting the test results
Y6_pred= regressor6.predict(X6_test)

#printing accuracy of model
accuracy6 = regressor6.score(X6_test,Y6_test)



'''Part 7: For Semester 7 Student who wants to predict semester 8 performance'''
#defining X and Y
X7= df.iloc[:,1:12].values
Y7= df.iloc[:,12].values

#Splitting the data
from sklearn.model_selection import train_test_split
X7_train, X7_test, Y7_train, Y7_test= train_test_split(X7,Y7,test_size= 1/10, random_state=1)

#Fitting Simple Linear Regression 
#This is called Model 
from sklearn.linear_model import LinearRegression
regressor7= LinearRegression()
regressor7.fit(X7_train,Y7_train)

##Predicting the test results
Y7_pred= regressor7.predict(X7_test)

#printing accuracy of model
accuracy7 = regressor7.score(X7_test,Y7_test)
#print(accuracy7*100)
#accuracy7*100,'%'

sample_test= pd.read_excel('Sample test.xlsx')
result= regressor5.predict(sample_test)
print('Dear User, If your cur rent learning habits remains same your next semester SGPA is expected to be ',result)
#
##
###
####
#####
######
#######
#########
###########
###############
######################
####################################
##############################################

from docx import Document 
from docx.shared import Inches

document= Document()
document.add_heading("Educational Data Mining System")
document.add_paragraph("Dear")
document.add_paragraph("Thanks for using EDM for your Accademic Performance. As per your historical data we have come to conclusion that if your learning habits remains same, your next sem SGPA is expected to be ")
document.save('Student Report.docx')


"""
Created on Mon Jun  10 11:14:25 2019
Projct- Student Performance analysis [Domain Prediction Module] using Educational Data Mining [EDM]
@author: Vedant Bahel
"""
dd= pd.read_excel('Domain.xlsx')

Xd= dd.iloc[:,0:13].values
Yd= dd.iloc[:,13].values

from sklearn.linear_model import LogisticRegression
regressord= LogisticRegression()
regressord.fit(Xd,Yd)

d_test= pd.read_excel('Sampled.xlsx')
resultd= regressord.predict(d_test)
print('Dear User, As per our model it is suggested for you to join ',resultd)
print('Where 1=Toastmasters: 2= IEEE: 3=Ecell')
